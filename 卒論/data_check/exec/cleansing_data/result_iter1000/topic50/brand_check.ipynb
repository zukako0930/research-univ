# %%
import pandas as pd

# %%
brands=pd.read_csv('pattern003/topic28brands.csv')
tags=pd.read_csv('pattern003/topic28tags.csv')

# %%
print(brands[0:10],tags[0:10])
# Out:
#                             0     1
# 0        Spick and Span Noble  61.0
# 1                  SLOBE IENA  34.0
# 2              Odette e Odile  31.0
# 3             31 Sons de mode  30.0
# 4  BEAUTY&YOUTH UNITED ARROWS  27.0
# 5                    RODE SKO  27.0
# 6               ADAM ET ROPE'  27.0
# 7                Spick & Span  27.0
# 8                 select MOCA  23.0
# 9        URBAN RESEARCH ROSSO  22.0            0     1
# 0      大人コーデ  32.0
# 1      オトナ女子  29.0
# 2       パンプス  22.0
# 3    タイトスカート  13.0
# 4        グレー  13.0
# 5      はるコーデ  13.0
# 6  きれいめカジュアル  12.0
# 7     チビーズ✳︎  12.0
# 8   ママファッション  10.0
# 9  パーティースタイル  10.0

# %%
brands=brands.rename(columns={'0':'brand','1':'counts'})
tags=tags.rename(columns={'0':'tag','1':'counts'})

# %%
brands.counts=brands.counts/brands['counts'].sum()

# %%
brands
# Out:
#                           brand    counts
# 0          Spick and Span Noble  0.070602
# 1                    SLOBE IENA  0.039352
# 2                Odette e Odile  0.035880
# 3               31 Sons de mode  0.034722
# 4    BEAUTY&YOUTH UNITED ARROWS  0.031250
# 5                      RODE SKO  0.031250
# 6                 ADAM ET ROPE'  0.031250
# 7                  Spick & Span  0.031250
# 8                   select MOCA  0.026620
# 9          URBAN RESEARCH ROSSO  0.025463
# 10                nano・universe  0.025463
# 11               URBAN RESEARCH  0.024306
# 12                    Mila Owen  0.019676
# 13                  Accessorize  0.018519
# 14                 ROPE' PICNIC  0.017361
# 15                        ROSSO  0.015046
# 16             JOURNAL STANDARD  0.015046
# 17                FREAK'S STORE  0.013889
# 18                    Casselini  0.013889
# 19                  Chille anap  0.013889
# 20                         reca  0.012731
# 21   URBAN RESEARCH Sonny Label  0.012731
# 22                       LAYMEE  0.012731
# 23              SHIPS for women  0.012731
# 24                     DESCENTE  0.012731
# 25                    FRAMeWORK  0.012731
# 26                          ViS  0.012731
# 27                     CONVERSE  0.011574
# 28              Another Edition  0.011574
# 29                         IENA  0.011574
# ..                          ...       ...
# 97                   FRUIT CAKE  0.001157
# 98                   Marie Hill  0.001157
# 99                  PACO POVEDA  0.001157
# 100               FABIO RUSCONI  0.001157
# 101                          坩堝  0.001157
# 102                    folklore  0.001157
# 103               Afternoon Tea  0.001157
# 104        ROPÉ PICNIC（ロペピクニック）  0.001157
# 105                  BETON CIRE  0.001157
# 106                 La TOTALITE  0.001157
# 107                 Loungedress  0.001157
# 108                      induna  0.001157
# 109                  mature ha.  0.001157
# 110                      snidel  0.001157
# 111               JANESSA LEONE  0.001157
# 112                SEE BY CHLOE  0.001157
# 113           JETSET SOLO PLUS   0.001157
# 114                  Bonappetit  0.001157
# 115                   JANESMITH  0.001157
# 116              Usagi pour toi  0.001157
# 117               Jewel Changes  0.001157
# 118               STUDIOUS CITY  0.001157
# 119        BURBERRY BLACK LABEL  0.001157
# 120                Settimissimo  0.001157
# 121                  CABIN ZERO  0.001157
# 122            COMME CA DU MODE  0.001157
# 123               MARY AL TERNA  0.001157
# 124                       YANUK  0.001157
# 125            Boisson Chocolat  0.001157
# 126                 SCYE BASICS  0.001157
#
# [127 rows x 2 columns]
